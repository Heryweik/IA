# %%
import pandas as pd
df = pd.read_json('Alumnos.json')
df
# Out:
#     id primer_nombre         apellido                            email  \
# 0    1      Iolanthe            Lumox          ilumox0@dailymotion.com
# 1    2        Stacee         Kingcote       skingcote1@stumbleupon.com
# 2    3         Leigh        Pesticcio       lpesticcio2@purevolume.com
# 3    4          Fitz         Grissett               fgrissett3@nps.gov
# 4    5           Sid          Stealey              sstealey4@unblog.fr
# 5    6        Julius         Butteris          jbutteris5@multiply.com
# 6    7        Wilmar           Fucher           wfucher6@indiegogo.com
# 7    8        Kelbee             Poli                 kpoli7@europa.eu
# 8    9         Gerik         Wrathall               gwrathall8@mapy.cz
# 9   10          Yuri          Poletto          ypoletto9@canalblog.com
# 10  11         Rhody         Girodier        rgirodiera@feedburner.com
# 11  12         Linda         Taberner              ltabernerb@furl.net
# ...

# %%
dt = pd.read_csv('Universidad.csv')
dt
# Out:
#     id                                        universidad  \
# 0    1                  Western Mindanao State University
# 1    2                              University of Calgary
# 2    3   COMSATS Institute of Information Technology, Wah
# 3    4                         Togliatti State University
# 4    5                         Dalarna University College
# 5    6                           Politeknik Negeri Padang
# 6    7                          Open University of Israel
# 7    8          Tianjin University of Finance & Economics
# 8    9  Instituto de Artes Visuais, Design e Marketing...
# 9   10                          Midlands State University
# 10  11                             Universitas Simalungun
# 11  12  Chengdu Institute of Sichuan International Stu...
# 12  13  Pontifícia Universidade Católica do Rio Grande...
# 13  14        Shanghai Ouhua Vocational Technical College
# 14  15                    Dimocritus University of Thrace
# ...

# %%
pd.merge(df, dt, on='id')
# Out:
#     id primer_nombre         apellido                          email_x  \
# 0    1      Iolanthe            Lumox          ilumox0@dailymotion.com
# 1    2        Stacee         Kingcote       skingcote1@stumbleupon.com
# 2    3         Leigh        Pesticcio       lpesticcio2@purevolume.com
# 3    4          Fitz         Grissett               fgrissett3@nps.gov
# 4    5           Sid          Stealey              sstealey4@unblog.fr
# 5    6        Julius         Butteris          jbutteris5@multiply.com
# 6    7        Wilmar           Fucher           wfucher6@indiegogo.com
# 7    8        Kelbee             Poli                 kpoli7@europa.eu
# 8    9         Gerik         Wrathall               gwrathall8@mapy.cz
# 9   10          Yuri          Poletto          ypoletto9@canalblog.com
# 10  11         Rhody         Girodier        rgirodiera@feedburner.com
# 11  12         Linda         Taberner              ltabernerb@furl.net
# ...

# %%
df.primer_nombre[df.indice==df.indice.max()] #Alumnos con mayor indice
# Out:
# 11    Linda
# 39    Virge
# Name: primer_nombre, dtype: object

# %%
dt.universidad[dt.pais=='China'] #Universidades de China
# Out:
# 7             Tianjin University of Finance & Economics
# 11    Chengdu Institute of Sichuan International Stu...
# 13          Shanghai Ouhua Vocational Technical College
# 18                        Guangzhou Academy of Fine Art
# 20    Fujian University of Traditional Chinese Medicine
# 22    University of Electronic Science and Technolog...
# 25                           Northwest University Xi'an
# 33                                 Zhongshan University
# 35                          Guangzhou Normal University
# 37                          Beijing New Asia University
# 38                                  Shaoguan University
# 49                            Xi'an Academy of Fine Art
# Name: universidad, dtype: object

# %%
df[['primer_nombre','apellido']][df.indice>85] #Alumnos con indice mayor a 85
# Out:
#    primer_nombre         apellido
# 1         Stacee         Kingcote
# 3           Fitz         Grissett
# 10         Rhody         Girodier
# 11         Linda         Taberner
# 12     Heindrick          Sillett
# 13       Isadore      Twelvetrees
# 15        Peyter         Bourdice
# 21       Melodie           Steart
# 23         Gregg           Peinke
# 26          Gage            Epine
# 29       Jacenta           Caldow
# 30         Minne            Diess
# 34         Fayre       O'Cannavan
# 39         Virge        Cleynaert
# 41         Valry            Corse
# 42        Lilith         Thorburn
# 46        Nicoli            Tomsa
# 49        Tildie  de'-Ancy Willis
